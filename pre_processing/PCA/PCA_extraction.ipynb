# %%
import os
import sys
import pandas as pd

operating_system = 'curnagl'

if operating_system == 'win':
    os.chdir('C:/Users/fabau/OneDrive/Documents/GitHub/master-project-cleaned/')
elif operating_system == 'curnagl':
    os.chdir('/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/cleaner_version/')
    path = os.getcwd()
else:
    os.chdir('/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/')

# Add the path to the custom library
custom_library_path = os.path.abspath('util/processing/')
sys.path.append(custom_library_path)

import extraction_squares, time_series, pca

'''if operating_system == 'curnagl':
    name_of_variable= pd.read_csv('/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/curnagl/DATASETS/variable_list_80_mean.csv')
    path_data = '/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/curnagl/DATASETS'
else:'''
variables= pd.read_csv('data/variable_list_levels.csv')
path_data = 'data'

'''storm_dates = pd.read_csv('pre_processing/tracks/storm_dates.csv')
path_tracks_1h_EU = 'pre_processing/tracks/ALL_TRACKS/tracks_1h_EU'
path_tracks_1h_non_EU = 'pre_processing/tracks/ALL_TRACKS/tracks_1h_non_EU'
dataset = 'datasets_1h_EU'
dataset_non_EU = 'datasets_1h_non_EU'''
# Out:
# "storm_dates = pd.read_csv('pre_processing/tracks/storm_dates.csv')\npath_tracks_1h_EU = 'pre_processing/tracks/ALL_TRACKS/tracks_1h_EU'\npath_tracks_1h_non_EU = 'pre_processing/tracks/ALL_TRACKS/tracks_1h_non_EU'\ndataset = 'datasets_1h_EU'\ndataset_non_EU = 'datasets_1h_non_EU"

# %%
pca.to_pca_components(path,variables, 42, threshold=0.98)
# Out:
# Storm indices for training: [0, 1, 2, 4, 6, 7, 10, 11, 12, 15, 18, 20, 25, 26, 30, 31, 33, 38, 43, 46, 48, 49, 50, 52, 53, 55, 57, 61, 62, 63, 64, 66, 67, 68, 71, 72, 75, 76, 78, 79, 80, 82, 84, 88, 89, 94]
# Storm indices for test: [5, 28, 37, 44, 47, 65, 85, 86, 92]
# Storm indices for validation: [32, 42, 45, 59, 60, 70, 77, 81]
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for 10m_u_component_of_wind_max have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for 10m_u_component_of_wind_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for 10m_u_component_of_wind_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for 10m_u_component_of_wind_std have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for 10m_v_component_of_wind_max have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for 10m_v_component_of_wind_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for 10m_v_component_of_wind_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for 10m_v_component_of_wind_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for 2m_dewpoint_temperature_max have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for 2m_dewpoint_temperature_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for 2m_dewpoint_temperature_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for 2m_dewpoint_temperature_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for 2m_temperature_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for 2m_temperature_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for 2m_temperature_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for 2m_temperature_std have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for convective_available_potential_energy_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for convective_available_potential_energy_min have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for convective_available_potential_energy_mean have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for convective_available_potential_energy_std have been saved
# We want to keep 98.0 % of the variance, so we need 20 components
# PCA scores for convective_precipitation_max have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for convective_precipitation_min have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for convective_precipitation_mean have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for convective_precipitation_std have been saved
# We want to keep 98.0 % of the variance, so we need 21 components
# PCA scores for convective_rain_rate_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for convective_rain_rate_min have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for convective_rain_rate_mean have been saved
# We want to keep 98.0 % of the variance, so we need 17 components
# PCA scores for convective_rain_rate_std have been saved
# We want to keep 98.0 % of the variance, so we need 15 components
# PCA scores for convective_snowfall_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for convective_snowfall_min have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for convective_snowfall_mean have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for convective_snowfall_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_500_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_500_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_500_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_500_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_1000_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_1000_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_1000_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for geopotential_1000_std have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for high_cloud_cover_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for high_cloud_cover_min have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for high_cloud_cover_mean have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for high_cloud_cover_std have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for instantaneous_10m_wind_gust_max have been saved
# We want to keep 98.0 % of the variance, so we need 18 components
# PCA scores for instantaneous_10m_wind_gust_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for instantaneous_10m_wind_gust_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for instantaneous_10m_wind_gust_std have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for k_index_max have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for k_index_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for k_index_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for k_index_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for large_scale_precipitation_max have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for large_scale_precipitation_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for large_scale_precipitation_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for large_scale_precipitation_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for large_scale_snowfall_max have been saved
# We want to keep 98.0 % of the variance, so we need 2 components
# PCA scores for large_scale_snowfall_min have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for large_scale_snowfall_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for large_scale_snowfall_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_large_scale_precipitation_rate_max have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for mean_large_scale_precipitation_rate_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_large_scale_precipitation_rate_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for mean_large_scale_precipitation_rate_std have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for mean_top_net_long_wave_radiation_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_top_net_long_wave_radiation_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_top_net_long_wave_radiation_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for mean_top_net_long_wave_radiation_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for mean_top_net_short_wave_radiation_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_top_net_short_wave_radiation_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for mean_top_net_short_wave_radiation_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_top_net_short_wave_radiation_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_total_precipitation_rate_max have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for mean_total_precipitation_rate_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_total_precipitation_rate_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for mean_total_precipitation_rate_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for mean_sea_level_pressure_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for mean_sea_level_pressure_min have been saved
# We want to keep 98.0 % of the variance, so we need 2 components
# PCA scores for mean_sea_level_pressure_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for mean_sea_level_pressure_std have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_surface_latent_heat_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_surface_latent_heat_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_surface_latent_heat_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for mean_surface_latent_heat_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_surface_sensible_heat_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_surface_sensible_heat_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_surface_sensible_heat_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for mean_surface_sensible_heat_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_surface_net_long_wave_radiation_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for mean_surface_net_long_wave_radiation_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_surface_net_long_wave_radiation_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for mean_surface_net_long_wave_radiation_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_surface_net_short_wave_radiation_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for mean_surface_net_short_wave_radiation_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_surface_net_short_wave_radiation_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_surface_net_short_wave_radiation_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for mean_vertically_integrated_moisture_divergence_max have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for mean_vertically_integrated_moisture_divergence_min have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for mean_vertically_integrated_moisture_divergence_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for mean_vertically_integrated_moisture_divergence_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_10_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_10_min have been saved
# We want to keep 98.0 % of the variance, so we need 2 components
# PCA scores for relative_humidity_10_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_10_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_20_max have been saved
# We want to keep 98.0 % of the variance, so we need 2 components
# PCA scores for relative_humidity_20_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_20_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_20_std have been saved
# We want to keep 98.0 % of the variance, so we need 2 components
# PCA scores for relative_humidity_30_max have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_30_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_30_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_30_std have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_50_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_50_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_50_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_50_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_70_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_70_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_70_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_70_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_100_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_100_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_100_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_100_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_150_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_150_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_150_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_150_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_200_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_200_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_200_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_200_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_250_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_250_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_250_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_250_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_300_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_300_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_300_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_300_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_400_max have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_400_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_400_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_400_std have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_500_max have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_500_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_500_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_500_std have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_600_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_600_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_600_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_600_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_700_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_700_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_700_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_700_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_800_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_800_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_800_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_800_std have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_850_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_850_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_850_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_850_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_900_max have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_900_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_900_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_900_std have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_925_max have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_925_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_925_mean have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_925_std have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_950_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_950_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_950_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_950_std have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_975_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_975_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_975_mean have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_975_std have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for relative_humidity_1000_max have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for relative_humidity_1000_min have been saved
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for relative_humidity_1000_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for relative_humidity_1000_std have been saved
# sea_surface_temperature is not taken into account
# We want to keep 98.0 % of the variance, so we need 3 components
# PCA scores for surface_pressure_max have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for surface_pressure_min have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for surface_pressure_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for surface_pressure_std have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for surface_latent_heat_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for surface_latent_heat_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for surface_latent_heat_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for surface_latent_heat_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for surface_sensible_heat_flux_max have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for surface_sensible_heat_flux_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for surface_sensible_heat_flux_mean have been saved
# We want to keep 98.0 % of the variance, so we need 4 components
# PCA scores for surface_sensible_heat_flux_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_10_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_10_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_10_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_10_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_20_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_20_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_20_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_20_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_30_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_30_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_30_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_30_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_50_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_50_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_50_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_50_std have been saved
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_70_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_70_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_70_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_70_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_100_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_100_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_100_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_100_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_150_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_150_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_150_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_150_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_200_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_200_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_200_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_200_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_250_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_250_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# PCA scores for specific_rain_water_content_250_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_250_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_300_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_300_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_300_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_300_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_400_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_400_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_400_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_400_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_500_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_500_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_500_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_500_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_600_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_600_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_600_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_600_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# PCA scores for specific_rain_water_content_700_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_700_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_700_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_700_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_800_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_800_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_800_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_800_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_850_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_850_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_850_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_850_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_900_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_900_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_900_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_900_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_925_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_925_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_925_mean have been saved
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_925_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_950_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_950_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_950_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_950_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_975_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_975_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_975_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_975_std have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_1000_max have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_1000_min have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_1000_mean have been saved
# We want to keep 98.0 % of the variance, so we need 1 components
# PCA scores for specific_rain_water_content_1000_std have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for total_precipitation_max have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for total_precipitation_min have been saved
# We want to keep 98.0 % of the variance, so we need 5 components
# PCA scores for total_precipitation_mean have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for total_precipitation_std have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /work/FAC/FGSE/IDYST/tbeucler/default/fabien/conda_env/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# PCA scores for total_totals_index_max have been saved
# We want to keep 98.0 % of the variance, so we need 8 components
# PCA scores for total_totals_index_min have been saved
# We want to keep 98.0 % of the variance, so we need 6 components
# PCA scores for total_totals_index_mean have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for total_totals_index_std have been saved
# We want to keep 98.0 % of the variance, so we need 11 components
# PCA scores for vertical_velocity_10_max have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_10_min have been saved
# We want to keep 98.0 % of the variance, so we need 17 components
# PCA scores for vertical_velocity_10_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_10_std have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_20_max have been saved
# We want to keep 98.0 % of the variance, so we need 17 components
# PCA scores for vertical_velocity_20_min have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_20_mean have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_20_std have been saved
# We want to keep 98.0 % of the variance, so we need 17 components
# PCA scores for vertical_velocity_30_max have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_30_min have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_30_mean have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_30_std have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_50_max have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_50_min have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_50_mean have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_50_std have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_70_max have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_70_min have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_70_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_70_std have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_100_max have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_100_min have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_100_mean have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_100_std have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_150_max have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_150_min have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_150_mean have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_150_std have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_200_max have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_200_min have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_200_mean have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_200_std have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_250_max have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_250_min have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_250_mean have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_250_std have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_300_max have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_300_min have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_300_mean have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_300_std have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_400_max have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_400_min have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_400_mean have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_400_std have been saved
# We want to keep 98.0 % of the variance, so we need 7 components
# PCA scores for vertical_velocity_500_max have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_500_min have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_500_mean have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_500_std have been saved
# We want to keep 98.0 % of the variance, so we need 12 components
# PCA scores for vertical_velocity_600_max have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_600_min have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_600_mean have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for vertical_velocity_600_std have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_700_max have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_700_min have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for vertical_velocity_700_mean have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_700_std have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_800_max have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for vertical_velocity_800_min have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_800_mean have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_800_std have been saved
# We want to keep 98.0 % of the variance, so we need 9 components
# PCA scores for vertical_velocity_850_max have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_850_min have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_850_mean have been saved
# We want to keep 98.0 % of the variance, so we need 15 components
# PCA scores for vertical_velocity_850_std have been saved
# We want to keep 98.0 % of the variance, so we need 13 components
# PCA scores for vertical_velocity_900_max have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_900_min have been saved
# We want to keep 98.0 % of the variance, so we need 15 components
# PCA scores for vertical_velocity_900_mean have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_900_std have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_925_max have been saved
# We want to keep 98.0 % of the variance, so we need 15 components
# PCA scores for vertical_velocity_925_min have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_925_mean have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for vertical_velocity_925_std have been saved
# We want to keep 98.0 % of the variance, so we need 15 components
# PCA scores for vertical_velocity_950_max have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_950_min have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for vertical_velocity_950_mean have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_950_std have been saved
# We want to keep 98.0 % of the variance, so we need 10 components
# PCA scores for vertical_velocity_975_max have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for vertical_velocity_975_min have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_975_mean have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for vertical_velocity_975_std have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for vertical_velocity_1000_max have been saved
# We want to keep 98.0 % of the variance, so we need 16 components
# PCA scores for vertical_velocity_1000_min have been saved
# We want to keep 98.0 % of the variance, so we need 14 components
# PCA scores for vertical_velocity_1000_mean have been saved
# We want to keep 98.0 % of the variance, so we need 11 components
# PCA scores for vertical_velocity_1000_std have been saved
